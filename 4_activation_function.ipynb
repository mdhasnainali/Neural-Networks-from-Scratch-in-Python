# %% [markdown]
# ### Activation Function

# %%
import numpy as np

# %% [markdown]
# #### ReLU

# %%
# ReLU Activation

inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = []
for i in inputs:
    if i > 0:
        output.append(i)
    else:
        output.append(0)
print(output)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %%
# Optimized Coding Style for ReLU

inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = []
for i in inputs:
    output.append(max(0, i))
print(output)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %%
# ReLU using numpy

inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = np.maximum(0,inputs)
print(output)
# Out:
# [0.  2.  0.  3.3 0.  1.1 2.2 0. ]

# %%
# ReLU activation
class Activation_ReLU:
    # Forward pass
    def forward(self, inputs):
        # Calculate output values from input 
        self.output = np.maximum(0, inputs)

# %%
# From 3_add_more_layers.ipynb file

# Dense layer
class Layer_Dense:
    # Layer initialization
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    # Forward pass
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases

# %%
 # Create dataset
X, y = spiral_data(samples=100, classes=3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)
# Create ReLU activation (to be used with Dense layer):
activation1 = Activation_ReLU()
# Make a forward pass of our training data through this layer
dense1.forward(X)
# Forward pass through activation func.
# Takes in output from previous layer
activation1.forward(dense1.output)

# Let's see output of the first few samples:
print(activation1.output[:5])
# Out:
# [[0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [1.0037388e-04 0.0000000e+00 1.5741838e-04]
#  [2.9792593e-04 0.0000000e+00 2.5045680e-04]
#  [0.0000000e+00 5.7675607e-05 4.0088309e-04]
#  [2.5670546e-05 6.0695314e-05 5.9398217e-04]]

# %% [markdown]
# #### Softmax

# %%
# Values from the previous output when we described
# what a neural network is
layer_outputs = [4.8, 1.21, 2.385]
# e - mathematical constant, we use E here to match a common coding
# style where constants are uppercased
E = 2.71828182846  # you can also use math.e
# For each value in a vector, calculate the exponential value
exp_values = []
for output in layer_outputs:
    exp_values.append(E ** output)  # ** - power operator in Python
print('exponentiated values:')
print(exp_values)
# Out:
# exponentiated values:
# [121.51041751893969, 3.3534846525504487, 10.85906266492961]

# %%
# Now normalize values
norm_base = sum(exp_values)  # We sum all values
norm_values = []
for value in exp_values:
    norm_values.append(value / norm_base)
print('Normalized exponentiated values:')
print(norm_values)
print('Sum of normalized values:', sum(norm_values))
# Out:
# Normalized exponentiated values:
# [0.8952826639573506, 0.024708306782070668, 0.08000902926057876]
# Sum of normalized values: 1.0

# %%
# Using numpy

# Values from the earlier previous when we described
# what a neural network is
layer_outputs = [4.8, 1.21, 2.385]
# For each value in a vector, calculate the exponential value
exp_values = np.exp(layer_outputs)
print('exponentiated values:')
print(exp_values)
# Now normalize values
norm_values = exp_values / np.sum(exp_values)
print('normalized exponentiated values:')
print(norm_values)
print('sum of normalized values:', np.sum(norm_values))
# Out:
# exponentiated values:
# [121.51041752   3.35348465  10.85906266]
# normalized exponentiated values:
# [0.89528266 0.02470831 0.08000903]
# sum of normalized values: 0.9999999999999999

# %%
# To make it useful for training 

# Get unnormalized probabilities
exp_values = np.exp(inputs)
# Normalize them for each sample
probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)  # The values are in 2D array

# %%
# Try understand 
exp_values = [[1, 2, 3],
     [4,5,6],
     [7,8,9]]

b = np.sum(exp_values) # Sum all
c = np.sum(exp_values, axis=1) # Column wise sum
d = np.sum(exp_values, axis=1, keepdims=True) # Maintain the shape: 2D

print(b)
print(c)
print(d)
# Out:
# 45
# [ 6 15 24]
# [[ 6]
#  [15]
#  [24]]

# %%
# Softmax activation
class Activation_Softmax: # Forward pass
    def forward(self, inputs):
        # Get unnormalized probabilities
        exp_values = np.exp(inputs - np.max(inputs, axis=1,keepdims=True)) 
        probabilities = exp_values / np.sum(exp_values, axis=1,keepdims=True)
        self.output = probabilities

# %%
# Now we have a problem. Let's see
np.exp(1000)   # Overflow
# Out:
# /var/folders/lr/77q7001j7ts8dyg69j0vmc480000gn/T/ipykernel_17109/3378416299.py:2: RuntimeWarning: overflow encountered in exp
#   np.exp(1000)
# inf

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
# To solve this issue we subtract the maximum value from all the element. Because, if the result is negative, then it will be in the range in [0,1]

# %%
# Final Code 

import numpy as np
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

# Dense layer
class Layer_Dense:
    # Layer initialization
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons) 
        self.biases = np.zeros((1, n_neurons))
        # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs, weights and biases 
        self.output = np.dot(inputs, self.weights) + self.biases
    
# ReLU activation
class Activation_ReLU:
    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs 
        self.output = np.maximum(0, inputs)


# Softmax activation
class Activation_Softmax:  # Forward pass
    def forward(self, inputs):
        # Get unnormalized probabilities
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities

# %%
# Create dataset
X, y = spiral_data(samples=100, classes=3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)
# Create ReLU activation (to be used with Dense layer):
activation1 = Activation_ReLU()
# Create second Dense layer with 3 input features (as we take output
# of previous layer here) and 3 output values
dense2 = Layer_Dense(3, 3)
# Create Softmax activation (to be used with Dense layer):
activation2 = Activation_Softmax()
# Make a forward pass of our training data through this layer
dense1.forward(X)
# Make a forward pass through activation function
# it takes the output of first dense layer here
activation1.forward(dense1.output)
# Make a forward pass through second Dense layer
# it takes outputs of activation function of first layer as inputs
dense2.forward(activation1.output)
# Make a forward pass through activation function
# it takes the output of second dense layer here
activation2.forward(dense2.output)
# Let's see output of the first few samples:
print(activation2.output[:5])
# Out:
# [[0.33333334 0.33333334 0.33333334]
#  [0.33333316 0.3333332  0.33333364]
#  [0.33333287 0.3333329  0.33333418]
#  [0.3333326  0.33333263 0.33333477]
#  [0.33333233 0.3333324  0.33333528]]
